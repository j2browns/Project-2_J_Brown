# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import requests
import json
from sqlalchemy import create_engine

# %%
golf_data = pd.read_csv("results\MissRiver_golf_details.csv")

# %%
golf_data.head()
# Out:
#    course_id                                            course         city  \
# 0        607                                       Eagle Crest         Alma
# 1        611                 Millwood Landing Golf & RV Resort      Ashdown
# 2        616  Country Club at Bella Vista Village Golf Courses  Bella Vista
# 3        617     Highlands at Bella Vista Village Golf Courses  Bella Vista
# 4        618     Kingswood at Bella Vista Village Golf Courses  Bella Vista
#
#       state                   street  zip_code        lng        lat  hole  \
# 0  Arkansas  3926 Golf Course Drive,     72921 -94.167763  35.500004    18
# 1  Arkansas              596 Hwy 317     71822 -94.011486  33.717971    18
# 2  Arkansas          101 Town Center     72714 -94.249018  36.475194    18
# 3  Arkansas          101 Town Center     72714 -94.249018  36.475194    18
# 4  Arkansas          101 Town Center     72714 -94.249018  36.475194    18
#
# ...

# %% [markdown]
# miss_river = load.json("results\miss_river.json")

# %%
miss_river = json.load("results\miss_river.json")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-22f1e22b3bd0> in <module>
# ----> 1 miss_river = json.load("results\miss_river.json")
#
# ~\anaconda3\envs\NewPythonData\lib\json\__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     294
#     295     """
# --> 296     return loads(fp.read(),
#     297         cls=cls, object_hook=object_hook,
#     298         parse_float=parse_float, parse_int=parse_int,
#
# AttributeError: 'str' object has no attribute 'read'
