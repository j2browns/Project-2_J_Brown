# %%
#Importing required functions
import numpy as np
import pandas as pd
import datetime as dt
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func,  inspect, distinct
from sqlalchemy.types import Integer, Text, String, DateTime
from config import ckey, username, password
from flask import Flask, jsonify

# %%
#Setting up connection to SQL-Lite and Base Connections
#This work is based on testing in Jupyter Notebook from Same Assignment
engine = create_engine(f'postgresql://{username}:{password}@localhost:5432/Golf')
Base = automap_base()
Base.prepare(engine, reflect=True)
#creating object for measurement and station
golf_details = Base.classes.golf_details

session = Session(engine)

# %%
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['golf_details']

# %%
headings = []
columns_df = []
columns = inspector.get_columns('golf_details')
for c in columns:
    print(c['name'], c["type"])
    headings.append(f"golf_details.{c['name']}")
    columns_df.append( c['name'])
# Out:
# course_id INTEGER
# course VARCHAR(50)
# city VARCHAR(50)
# state VARCHAR(20)
# street VARCHAR(50)
# zip_code VARCHAR(20)
# lng VARCHAR(20)
# lat VARCHAR(20)
# hole VARCHAR(4)
# public_private VARCHAR(20)
# golf_season VARCHAR(30)
# beg_mnth VARCHAR(4)
# end_mnth VARCHAR(4)
# championship_par VARCHAR(4)
# championship_yards VARCHAR(6)
# championship_slope VARCHAR(6)
# championship_usga VARCHAR(6)
# middle_par VARCHAR(6)
# middle_yards VARCHAR(6)
# middle_slope VARCHAR(6)
# middle_usga VARCHAR(6)
# forward_par VARCHAR(6)
# forward_yards VARCHAR(6)
# forward_slope VARCHAR(6)
# forward_usga VARCHAR(6)

# %%
headings
# Out:
# ['golf_details.course_id',
#  'golf_details.course',
#  'golf_details.city',
#  'golf_details.state',
#  'golf_details.street',
#  'golf_details.zip_code',
#  'golf_details.lng',
#  'golf_details.lat',
#  'golf_details.hole',
#  'golf_details.public_private',
#  'golf_details.golf_season',
#  'golf_details.beg_mnth',
#  'golf_details.end_mnth',
#  'golf_details.championship_par',
#  'golf_details.championship_yards',
#  'golf_details.championship_slope',
#  'golf_details.championship_usga',
#  'golf_details.middle_par',
#  'golf_details.middle_yards',
#  'golf_details.middle_slope',
#  'golf_details.middle_usga',
#  'golf_details.forward_par',
#  'golf_details.forward_yards',
#  'golf_details.forward_slope',
#  'golf_details.forward_usga']

# %%
sel = [ golf_details.course_id,golf_details.course,golf_details.city,golf_details.state,
      golf_details.street,golf_details.zip_code,golf_details.lng,golf_details.lat,
      golf_details.hole,golf_details.public_private,golf_details.golf_season,
      golf_details.beg_mnth,golf_details.end_mnth,
      golf_details.championship_par, golf_details.championship_yards,golf_details.championship_slope,golf_details.championship_usga,
      golf_details.middle_par,golf_details.middle_yards, golf_details.middle_slope,golf_details.middle_usga,
      golf_details.forward_par, golf_details.forward_yards, golf_details.forward_slope,golf_details.forward_usga]#pulling only date and precipitation.
golf_data = session.query(*sel).all()

# %%
session.close()

# %%
golf_df = pd.DataFrame(columns = columns_df)
print(len(golf_data))
for i in range(0, len(golf_data)):
    record = golf_data[i]
    temp = []
    for j in range(0,len(columns_df)):
        temp.append(record[j])
    golf_df.loc[i]=temp
# Out:
# 69

# %%
golf_df
# Out:
#    course_id                             course             city  \
# 0       6390             Crestview Country Club           Agawam
# 1       6393         Hickory Ridge Country Club          Amherst
# 2       6445              Chicopee Country Club         Chicopee
# 3       6466              Elmcrest Country Club  East Longmeadow
# 4       6474                Oak Ridge Golf Club    Feeding Hills
# ..       ...                                ...              ...
# 64      1632  Carlton Oaks Lodge & Country Club           Santee
# 65      1647        Lomas Santa Fe Country Club     Solana Beach
# 66      1756              Shadowridge Golf Club            Vista
# 67      1757          Vista Valley Country Club            Vista
# 68      1765               Warner Springs Ranch   Warner Springs
#
#             state                  street zip_code                 lng  \
# 0   Massachusetts            Shoemaker Ln    01001         -72.6584404
# 1   Massachusetts        191 W Pomeroy Ln    01002          -72.528673
# 2   Massachusetts         1290 Burnett Rd    01020          -72.519452
# 3   Massachusetts      105 Somersville Rd    01028  -72.47500939999999
# 4   Massachusetts      850 S Westfield St    01030  -72.67516719999999
# ..            ...                     ...      ...                 ...
# 64     California          9200 Inwood Dr    92071        -117.0097332
# 65     California  1505 Lomas Santa Fe Dr    92075        -117.2402414
# 66     California         1980 Gateway Dr    92083        -117.2304337
# 67     California   29354 Vista Valley Dr    92084        -117.1973911
# 68     California            31652 Hwy 79    92086        -116.6341007
#
#            lat hole public_private  ... championship_slope championship_usga  \
# 0   42.0508369   18        Private  ...                128             73.40
# 1    42.343113   18   Semi-Private  ...                129             72.50
# 2    42.182502   18         Public  ...                126             73.00
# 3   42.0364835   18        Private  ...                120             70.20
# 4   42.0398023   18   Semi-Private  ...                124             71.20
# ..         ...  ...            ...  ...                ...               ...
# 64  32.8421584   18         Resort  ...                137             74.60
# 65  32.9951403   18        Private  ...                128             72.30
# 66  33.1686659   18        Private  ...                124             73.10
# 67  33.2511708   18        Private  ...                130             71.10
# 68  33.2831525   18        Private  ...                121             71.70
#
#    middle_par middle_yards middle_slope middle_usga forward_par forward_yards  \
# 0          72         6695          124       72.30          73          5571
# 1          74         6427          128       71.10          74          5340
# 2          71         6109          120       70.40          71          5123
# 3          70         5904          115       68.10          72          5363
# 4          70         6390          120       70.00          70          5297
# ..        ...          ...          ...         ...         ...           ...
# 64         72         6537          127       71.30          72          4537
# 65         72         6208          122       70.00          72          5830
# 66         72         6361          114       69.90          72          5693
# 67         71         6035          125       69.60          71          5627
# 68         72         6252          116       69.10          72          5470
#
#    forward_slope forward_usga
# 0            110        66.70
# 1            117        70.40
# 2            115        72.40
# 3            119        70.90
# 4            124        70.00
# ..           ...          ...
# 64           114        67.10
# 65           138        76.10
# 66           135        74.90
# 67           133        74.40
# 68           119        70.90
#
# [69 rows x 25 columns]

# %%
golf_test = (golf_df.to_json(orient = 'records', force_ascii = True))
golf_test
# Out:
# '[{"course_id":6390,"course":"Crestview Country Club","city":"Agawam","state":"Massachusetts","street":"Shoemaker Ln","zip_code":"01001","lng":"-72.6584404","lat":"42.0508369","hole":"18","public_private":"Private","golf_season":"Open: 4\\/01 Closed: 11\\/30","beg_mnth":"4","end_mnth":"11","championship_par":"72","championship_yards":"6902","championship_slope":"128","championship_usga":"73.40","middle_par":"72","middle_yards":"6695","middle_slope":"124","middle_usga":"72.30","forward_par":"73","forward_yards":"5571","forward_slope":"110","forward_usga":"66.70"},{"course_id":6393,"course":"Hickory Ridge Country Club","city":"Amherst","state":"Massachusetts","street":"191 W Pomeroy Ln","zip_code":"01002","lng":"-72.528673","lat":"42.343113","hole":"18","public_private":"Semi-Private","golf_season":"Open: 4\\/01 Closed: 12\\/01","beg_mnth":"4","end_mnth":"11","championship_par":"74","championship_yards":"6794","championship_slope":"129","championship_usga":"72.50","middle_par":"74","middle_yards":"6427","middle_slope":"128","middle_usga":"71.10","forward_par":"74","forward_yards":"5340","forward_slope":"117","forward_usga":"70.40"},{"course_id":6445,"course":"Chicopee Country Club","city":"Chicopee","state":"Massachusetts","street":"1290 Burnett Rd","zip_code":"01020","lng":"-72.519452","lat":"42.182502","hole":"18","public_private":"Public","golf_season":"Open: 4\\/01 Closed: 11\\/30","beg_mnth":"4","end_mnth":"11","championship_par":"71","championship_yards":"6742","championship_slope":"126","championship_usga":"73.00","middle_par":"71","middle_yards":"6109","middle_slope":"120","middle_usga":"70.40","forward_par":"71","forward_yards":"5123","forward_slope":"115","forward_usga":"72.40"},{"course_id":6466,"course":"Elmcrest Country Club","city":"East Longmeadow","state":"Massachusetts","street":"105 Somersville Rd","zip_code":"01028","lng":"-72.47500939999999","lat":"42.0364835","hole":"18","public_private":"Private","golf_season":"Open: 4\\/01 Closed: 11\\/30","beg_mnth":"4","end_mnth":"11","championship_par":"70","championship_yards":"6347","championship_slope":"120","championship_usga":"70.20","middle_par":"70","middle_yards":"5904","middle_slope":"115","middle_usga":"68.10","forward_par":"72","forward_yards":"5363","forward_slope":"119","forward_usga":"70.90"},{"course_id":6474,"course":"Oak Ridge Golf Club","city":"Feeding Hills","state":"Massachusetts","street":"850 S Westfield St","zip_code":"01030","lng":"-72.67516719999999","lat":"42.0398023","hole":"18","public_private":"Semi-Private","golf_season":"Open: 3\\/15 Closed: 11\\/15","beg_mnth":"3","end_mnth":"11","championship_par":"70","championship_yards":"6754","championship_slope":"124","championship_usga":"71.20","middle_par":"70","middle_yards":"6390","middle_slope":"120","middle_usga":"70.00","forward_par":"70","forward_yards":"5297","forward_slope":"124","forward_usga":"70.00"},{"course_id":6476,"course":"St. Anne Country Club","city":"Feeding Hills","state":"Massachusetts","street":"781 Shoemaker Ln","zip_code":"01030","lng":"-72.664205","lat":"42.05488099999999","hole":"18","public_private":"Public","golf_season":"Open: 4\\/01 Closed: 11\\/30","beg_mnth":"4","end_mnth":"11","championship_par":"72","championship_yards":"6608","championship_slope":"116","championship_usga":"70.80","middle_par":"72","middle_yards":"6412","middle_slope":"115","middle_usga":"69.80","forward_par":"72","forward_yards":"5565","forward_slope":"115","forward_usga":"70.00"},{"course_id":6487,"course":"Westover Golf Club","city":"Granby","state":"Massachusetts","street":"S St","zip_code":"01033","lng":"-72.52762","lat":"42.22972499999999","hole":"18","public_private":"Public","golf_season":"Open: 4\\/01 Closed: 11\\/15","beg_mnth":"4","end_mnth":"11","championship_par":"72","championship_yards":"7025","championship_slope":"131","championship_usga":"73.70","middle_par":"72","middle_yards":"6610","middle_slope":"129","middle_usga":"71.70","forward_par":"72","forward_yards":"5600","forward_slo ...

# %%
jsonify(golf_test)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-26-88a033be4aab> in <module>
# ----> 1 jsonify(golf_test)
#
# ~\anaconda3\envs\NewPythonData\lib\site-packages\flask\json\__init__.py in jsonify(*args, **kwargs)
#     356     separators = (",", ":")
#     357
# --> 358     if current_app.config["JSONIFY_PRETTYPRINT_REGULAR"] or current_app.debug:
#     359         indent = 2
#     360         separators = (", ", ": ")
#
# ~\anaconda3\envs\NewPythonData\lib\site-packages\werkzeug\local.py in __getattr__(self, name)
#     345         if name == "__members__":
#     346             return dir(self._get_current_object())
# --> 347         return getattr(self._get_current_object(), name)
#     348
#     349     def __setitem__(self, key, value):
#
# ~\anaconda3\envs\NewPythonData\lib\site-packages\werkzeug\local.py in _get_current_object(self)
#     304         """
#     305         if not hasattr(self.__local, "__release_local__"):
# --> 306             return self.__local()
#     307         try:
#     308             return getattr(self.__local, self.__name__)
#
# ~\anaconda3\envs\NewPythonData\lib\site-packages\flask\globals.py in _find_app()
#      50     top = _app_ctx_stack.top
#      51     if top is None:
# ---> 52         raise RuntimeError(_app_ctx_err_msg)
#      53     return top.app
#      54
#
# RuntimeError: Working outside of application context.
#
# This typically means that you attempted to use functionality that needed
# to interface with the current application object in some way. To solve
# this, set up an application context with app.app_context().  See the
# documentation for more information.
